# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler
import joblib
sns.set(rc = {'figure.figsize':(12, 12)})

# %%
df = pd.read_csv('datasets\\Diabetes.csv', na_values=['missing', 'xx', 'x', '?', '-'])
df
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# 2    24.0     N
# 3    24.0     N
# 4    21.0     N
# ..    ...   ...
# 995  30.0     Y
# 996  37.2    Y
# 997  27.4    Y
# 998  40.5    Y
# 999  33.0    Y
#
# [1000 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
df.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# min       0.900000     0.000000     0.300000     0.200000     0.300000
# 25%       6.500000     4.000000     1.500000     0.900000     1.800000
# 50%       8.000000     4.800000     2.000000     1.100000     2.500000
# 75%      10.200000     5.600000     2.900000     1.300000     3.300000
# max      16.000000    10.300000    13.800000     9.900000     9.900000
#
#               VLDL          BMI
# count  1000.000000  1000.000000
# mean      1.854700    29.578020
# std       3.663599     4.962388
# min       0.100000    19.000000
# 25%       0.700000    26.000000
# 50%       0.900000    30.000000
# 75%       1.500000    33.000000
# max      35.000000    47.750000

# %%
df.drop(['ID', 'No_Pation'], axis=1, inplace=True)
df
# Out:
#     Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 0        F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 1        M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0     N
# 2        F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 3        F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 4        M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0     N
# ..     ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...   ...
# 995      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0     Y
# 996      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2    Y
# 997      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4    Y
# 998      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5    Y
# 999      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0    Y
#
# [1000 rows x 12 columns]

# %%
sns.stripplot(data=df, x='AGE')
# Out:
# <AxesSubplot:xlabel='AGE'>

# %%
df.loc[(df['AGE'] < 30) | (df['AGE'] > 70), 'AGE'] = np.nan

# %%
sns.stripplot(data=df, x='Urea')
# Out:
# <AxesSubplot:xlabel='Urea'>

# %%
df.loc[(df['Urea'] < 2) | (df['Urea'] > 12), 'Urea'] = np.nan

# %%
sns.stripplot(data=df, x='Cr')
# Out:
# <AxesSubplot:xlabel='Cr'>

# %%
df.loc[(df['Cr'] < 15) | (df['Cr'] > 150), 'Cr'] = np.nan

# %%
sns.stripplot(data=df, x='HbA1c')
# Out:
# <AxesSubplot:xlabel='HbA1c'>

# %%
df.loc[(df['HbA1c'] < 4) | (df['HbA1c'] > 14), 'HbA1c'] = np.nan

# %%
sns.stripplot(data=df, x='Chol')
# Out:
# <AxesSubplot:xlabel='Chol'>

# %%
df.loc[(df['Chol'] < 2.2) | (df['Chol'] > 7.5), 'Chol'] = np.nan

# %%
sns.stripplot(data=df, x='TG')
# Out:
# <AxesSubplot:xlabel='TG'>

# %%
df.loc[(df['TG'] < 0.4) | (df['TG'] > 5.5), 'TG'] = np.nan

# %%
sns.stripplot(data=df, x='HDL')
# Out:
# <AxesSubplot:xlabel='HDL'>

# %%
df.loc[df['HDL'] > 2.5, 'HDL'] = np.nan

# %%
sns.stripplot(data=df, x='LDL')
# Out:
# <AxesSubplot:xlabel='LDL'>

# %%
df.loc[(df['LDL'] < 0.7) | (df['LDL'] > 5.5), 'LDL'] = np.nan

# %%
sns.stripplot(data=df, x='VLDL')
# Out:
# <AxesSubplot:xlabel='VLDL'>

# %%
df.loc[df['VLDL'] > 4, 'VLDL'] = np.nan

# %%
sns.stripplot(data=df, x='BMI')
# Out:
# <AxesSubplot:xlabel='BMI'>

# %%
df.loc[(df['BMI'] < 18) | (df['BMI'] > 38.5), 'BMI'] = np.nan

# %%
df.isna().sum()
# Out:
# Gender     0
# AGE       27
# Urea      31
# Cr        29
# HbA1c     24
# Chol      41
# TG        28
# HDL       20
# LDL       17
# VLDL      62
# BMI       34
# CLASS      0
# dtype: int64

# %%
imputer = KNNImputer()
for col in df.columns[1:-1]:
    df[col] = imputer.fit_transform(df[[col]])

# %%
df.isna().sum()
# Out:
# Gender    0
# AGE       0
# Urea      0
# Cr        0
# HbA1c     0
# Chol      0
# TG        0
# HDL       0
# LDL       0
# VLDL      0
# BMI       0
# CLASS     0
# dtype: int64

# %%
def handle_output(output):
    return 1 if output == 'Y' else 0

df['CLASS'] = df['CLASS'].apply(handle_output)

# %%
df['Gender'] = df['Gender'].apply(str.upper)
df = pd.get_dummies(df, columns=['Gender'], drop_first=True)
df
# Out:
#            AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL      VLDL        BMI  \
# 0    50.000000   4.7  46.0    4.9   4.2  0.9  2.4  1.4  0.500000  24.000000
# 1    53.289825   4.5  62.0    4.9   3.7  1.4  1.1  2.1  0.600000  23.000000
# 2    50.000000   4.7  46.0    4.9   4.2  0.9  2.4  1.4  0.500000  24.000000
# 3    50.000000   4.7  46.0    4.9   4.2  0.9  2.4  1.4  0.500000  24.000000
# 4    33.000000   7.1  46.0    4.9   4.9  1.0  0.8  2.0  0.400000  21.000000
# ..         ...   ...   ...    ...   ...  ...  ...  ...       ...        ...
# 995  53.289825  11.0  97.0    7.0   7.5  1.7  1.2  1.8  0.600000  30.000000
# 996  31.000000   3.0  60.0   12.3   4.1  2.2  0.7  2.4  1.042751  37.200000
# 997  30.000000   7.1  81.0    6.7   4.1  1.1  1.2  2.4  1.042751  27.400000
# 998  38.000000   5.8  59.0    6.7   5.3  2.0  1.6  2.9  1.042751  29.206822
# 999  54.000000   5.0  67.0    6.9   3.8  1.7  1.1  3.0  0.700000  33.000000
#
#      CLASS  Gender_M
# 0        0         0
# 1        0         1
# 2        0         0
# 3        0         0
# 4        0         1
# ..     ...       ...
# 995      1         1
# 996      0         1
# 997      0         1
# 998      0         1
# 999      0         1
#
# [1000 rows x 12 columns]

# %%
sns.heatmap(df.corr(), annot=True, fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
df.drop(['Cr', 'HDL', 'LDL', 'Gender_M'], axis=1, inplace=True)

# %%
x = df.drop('CLASS', axis=1)
y = df['CLASS']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=32)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (750, 7)
# (750,)
# (250, 7)
# (250,)

# %%
y_train.value_counts()
# Out:
# 1    636
# 0    114
# Name: CLASS, dtype: int64

# %%
sampler = SMOTE()
x_train, y_train = sampler.fit_resample(x_train, y_train)
y_train.value_counts()
# Out:
# 0    636
# 1    636
# Name: CLASS, dtype: int64

# %%
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
models = {
    "LR": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "SVC": SVC(),
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(),
    "XGB": XGBClassifier(),
    "Naive Bayes": GaussianNB()
}

# %%
for name, model in models.items():
    print(f'Training Model {name} \n--------------')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'Training Accuracy: {accuracy_score(y_train, model.predict(x_train))}')
    print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
    print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
    print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
    print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
    print('-'*30)
# Out:
# Training Model LR
# --------------
# Training Accuracy: 0.9520440251572327
# Testing Accuracy: 0.912
# Testing Confusion Matrix:
# [[ 42   4]
#  [ 18 186]]
# Testing Recall: 0.9117647058823529
# Testing Precesion: 0.9789473684210527
# ------------------------------
# Training Model KNN
# --------------
# Training Accuracy: 0.9740566037735849
# Testing Accuracy: 0.944
# Testing Confusion Matrix:
# [[ 43   3]
#  [ 11 193]]
# Testing Recall: 0.946078431372549
# Testing Precesion: 0.9846938775510204
# ------------------------------
# Training Model SVC
# --------------
# Training Accuracy: 0.9740566037735849
# Testing Accuracy: 0.952
# Testing Confusion Matrix:
# [[ 42   4]
#  [  8 196]]
# Testing Recall: 0.9607843137254902
# Testing Precesion: 0.98
# ------------------------------
# Training Model DT
# --------------
# Training Accuracy: 0.9984276729559748
# Testing Accuracy: 0.984
# Testing Confusion Matrix:
# [[ 44   2]
#  [  2 202]]
# Testing Recall: 0.9901960784313726
# Testing Precesion: 0.9901960784313726
# ------------------------------
# Training Model RF
# --------------
# Training Accuracy: 0.9984276729559748
# Testing Accuracy: 0.968
# Testing Confusion Matrix:
# [[ 44   2]
#  [  6 198]]
# Testing Recall: 0.9705882352941176
# Testing Precesion: 0.99
# ------------------------------
# Training Model XGB
# --------------
# [16:55:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training Accuracy: 0.9984276729559748
# Testing Accuracy: 0.98
# Testing Confusion Matrix:
# [[ 44   2]
#  [  3 201]]
# Testing Recall: 0.9852941176470589
# Testing Precesion: 0.9901477832512315
# ------------------------------
# Training Model Naive Bayes
# --------------
# Training Accuracy: 0.9488993710691824
# Testing Accuracy: 0.924
# Testing Confusion Matrix:
# [[ 39   7]
#  [ 12 192]]
# Testing Recall: 0.9411764705882353
# Testing Precesion: 0.964824120603015
# ------------------------------
# C:\Users\moham\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(f'Training Accuracy: {accuracy_score(y_train, model.predict(x_train))}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
# Out:
# Training Accuracy: 0.9984276729559748
# Testing Accuracy: 0.984
# Testing Confusion Matrix:
# [[ 44   2]
#  [  2 202]]
# Testing Recall: 0.9901960784313726
# Testing Precesion: 0.9901960784313726

# %%
joblib.dump(scaler, 'vital_signs_scaler.h5')
joblib.dump(model, 'vital_signs_model.h5')
# Out:
# ['vital_signs_model.h5']
